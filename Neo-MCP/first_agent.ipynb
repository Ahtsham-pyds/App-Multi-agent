# %%
import asyncio
import os
from typing import Any
 
from dotenv import load_dotenv
from langchain_core.messages import AnyMessage
from langchain_core.messages.utils import count_tokens_approximately, trim_messages
from langchain_core.tools import StructuredTool
from langchain_mcp_adapters.tools import load_mcp_tools
from langgraph.checkpoint.memory import InMemorySaver
from langgraph.prebuilt import create_react_agent
#from langchain.agents import create_agent
from langgraph.prebuilt.chat_agent_executor import AgentState
#from langchain.agents import AgentState

from mcp import ClientSession, StdioServerParameters
from mcp.client.stdio import stdio_client
from neo4j import GraphDatabase, RoutingControl
from pydantic import BaseModel, Field

if load_dotenv():
    print("Loaded .env file")
else:
    print("No .env file found")
# Out:
# Loaded .env file

# %%
pip install mcp-neo4j-cypher
# Out:
# Requirement already satisfied: mcp-neo4j-cypher in c:\users\hahtsham\work\agent\lib\site-packages (0.5.1)
# Requirement already satisfied: fastmcp>=2.10.5 in c:\users\hahtsham\work\agent\lib\site-packages (from mcp-neo4j-cypher) (2.14.1)
# Requirement already satisfied: neo4j>=5.26.0 in c:\users\hahtsham\work\agent\lib\site-packages (from mcp-neo4j-cypher) (6.0.3)
# Requirement already satisfied: pydantic>=2.10.1 in c:\users\hahtsham\work\agent\lib\site-packages (from mcp-neo4j-cypher) (2.11.9)
# Requirement already satisfied: tiktoken>=0.11.0 in c:\users\hahtsham\work\agent\lib\site-packages (from mcp-neo4j-cypher) (0.12.0)
# Requirement already satisfied: authlib>=1.6.5 in c:\users\hahtsham\work\agent\lib\site-packages (from fastmcp>=2.10.5->mcp-neo4j-cypher) (1.6.6)
# Requirement already satisfied: cyclopts>=4.0.0 in c:\users\hahtsham\work\agent\lib\site-packages (from fastmcp>=2.10.5->mcp-neo4j-cypher) (4.3.0)
# Requirement already satisfied: exceptiongroup>=1.2.2 in c:\users\hahtsham\work\agent\lib\site-packages (from fastmcp>=2.10.5->mcp-neo4j-cypher) (1.3.1)
# Requirement already satisfied: httpx>=0.28.1 in c:\users\hahtsham\work\agent\lib\site-packages (from fastmcp>=2.10.5->mcp-neo4j-cypher) (0.28.1)
# Requirement already satisfied: jsonschema-path>=0.3.4 in c:\users\hahtsham\work\agent\lib\site-packages (from fastmcp>=2.10.5->mcp-neo4j-cypher) (0.3.4)
# Requirement already satisfied: mcp>=1.24.0 in c:\users\hahtsham\work\agent\lib\site-packages (from fastmcp>=2.10.5->mcp-neo4j-cypher) (1.24.0)
# Requirement already satisfied: openapi-pydantic>=0.5.1 in c:\users\hahtsham\work\agent\lib\site-packages (from fastmcp>=2.10.5->mcp-neo4j-cypher) (0.5.1)
# Requirement already satisfied: platformdirs>=4.0.0 in c:\users\hahtsham\work\agent\lib\site-packages (from fastmcp>=2.10.5->mcp-neo4j-cypher) (4.5.0)
# Requirement already satisfied: py-key-value-aio<0.4.0,>=0.3.0 in c:\users\hahtsham\work\agent\lib\site-packages (from py-key-value-aio[disk,keyring,memory]<0.4.0,>=0.3.0->fastmcp>=2.10.5->mcp-neo4j-cypher) (0.3.0)
# Requirement already satisfied: pydocket>=0.15.5 in c:\users\hahtsham\work\agent\lib\site-packages (from fastmcp>=2.10.5->mcp-neo4j-cypher) (0.15.5)
# Requirement already satisfied: pyperclip>=1.9.0 in c:\users\hahtsham\work\agent\lib\site-packages (from fastmcp>=2.10.5->mcp-neo4j-cypher) (1.11.0)
# Requirement already satisfied: python-dotenv>=1.1.0 in c:\users\hahtsham\work\agent\lib\site-packages (from fastmcp>=2.10.5->mcp-neo4j-cypher) (1.1.1)
# Requirement already satisfied: rich>=13.9.4 in c:\users\hahtsham\work\agent\lib\site-packages (from fastmcp>=2.10.5->mcp-neo4j-cypher) (14.1.0)
# Requirement already satisfied: uvicorn>=0.35 in c:\users\hahtsham\work\agent\lib\site-packages (from fastmcp>=2.10.5->mcp-neo4j-cypher) (0.37.0)
# Requirement already satisfied: websockets>=15.0.1 in c:\users\hahtsham\work\agent\lib\site-packages (from fastmcp>=2.10.5->mcp-neo4j-cypher) (15.0.1)
# Requirement already satisfied: py-key-value-shared==0.3.0 in c:\users\hahtsham\work\agent\lib\site-packages (from py-key-value-aio<0.4.0,>=0.3.0->py-key-value-aio[disk,keyring,memory]<0.4.0,>=0.3.0->fastmcp>=2.10.5->mcp-neo4j-cypher) (0.3.0)
# Requirement already satisfied: beartype>=0.20.0 in c:\users\hahtsham\work\agent\lib\site-packages (from py-key-value-aio<0.4.0,>=0.3.0->py-key-value-aio[disk,keyring,memory]<0.4.0,>=0.3.0->fastmcp>=2.10.5->mcp-neo4j-cypher) (0.22.9)
# Requirement already satisfied: typing-extensions>=4.15.0 in c:\users\hahtsham\work\agent\lib\site-packages (from py-key-value-shared==0.3.0->py-key-value-aio<0.4.0,>=0.3.0->py-key-value-aio[disk,keyring,memory]<0.4.0,>=0.3.0->fastmcp>=2.10.5->mcp-neo4j-cypher) (4.15.0)
# Requirement already satisfied: diskcache>=5.0.0 in c:\users\hahtsham\work\agent\lib\site-packages (from py-key-value-aio[disk,keyring,memory]<0.4.0,>=0.3.0->fastmcp>=2.10.5->mcp-neo4j-cypher) (5.6.3)
# Requirement already satisfied: pathvalidate>=3.3.1 in c:\users\hahtsham\work\agent\lib\site-packages (from py-key-value-aio[disk,keyring,memory]<0.4.0,>=0.3.0->fastmcp>=2.10.5->mcp-neo4j-cypher) (3.3.1)
# Requirement already satisfied: keyring>=25.6.0 in c:\users\hahtsham\work\agent\lib\site-packages (from py-key-value-aio[disk,keyring,memory]<0.4.0,>=0.3.0->fastmcp>=2.10.5->mcp-neo4j-cypher) (25.7.0)
# Requirement already satisfied: cachetools>=5.0.0 in c:\users\hahtsham\work\agent\lib\site-packages (from py-key-value-aio[disk,keyring,memory]<0.4.0,>=0.3.0->fastmcp>=2.10.5->mcp-neo4j-cypher) (6.2.3)
# Requirement already satisfied: cryptography in c:\users\hahtsham\work\agent\lib\site-packages (from authlib>=1.6.5->fastmcp>=2.10.5->mcp-neo4j-cypher) (46.0.2)
# Requirement already satisfied: attrs>=23.1.0 in c:\users\hahtsham\work\agent\lib\site-packages (from cyclopts>=4.0.0->fastmcp>=2.10.5->mcp-neo4j-cypher) (25.3.0)
# Requirement already satisfied: docstring-parser<4.0,>=0.15 in c:\users\hahtsham\work\agent\lib\site-packages (from cyclopts>=4.0.0->fastmcp>=2.10.5->mcp-neo4j-cypher) (0.17.0)
# Requirement already satisfied: rich-rst<2.0.0,>=1.3.1 in c:\users\hahtsham\work\agent\lib\site-packages (from cyclopts>=4.0.0->fastmcp>=2.10.5->mcp-neo4j-cypher) (1.3.2)
# Requirement already satisfied: docutils in c:\users\hahtsham\work\agent\lib\site-packages (from rich-rst<2.0.0,>=1.3.1->cyclopts>=4.0.0->fastmcp>=2.10.5->mcp-neo4j-cypher) (0.22.3)
# Requirement already satisfied: anyio in c:\users\hahtsham\work\agent\lib\site-packages (from httpx>=0.28.1->fastmcp>=2.10.5->mcp-neo4j-cypher) (4.11.0)
# Requirement already satisfied: certifi in c:\users\hahtsham\work\agent\lib\site-packages (from httpx>=0.28.1->fastmcp>=2.10.5->mcp-neo4j-cypher) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\hahtsham\work\agent\lib\site-packages (from httpx>=0.28.1->fastmcp>=2.10.5->mcp-neo4j-cypher) (1.0.9)
# Requirement already satisfied: idna in c:\users\hahtsham\work\agent\lib\site-packages (from httpx>=0.28.1->fastmcp>=2.10.5->mcp-neo4j-cypher) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\hahtsham\work\agent\lib\site-packages (from httpcore==1.*->httpx>=0.28.1->fastmcp>=2.10.5->mcp-neo4j-cypher) (0.16.0)
# Requirement already satisfied: PyYAML>=5.1 in c:\users\hahtsham\work\agent\lib\site-packages (from jsonschema-path>=0.3.4->fastmcp>=2.10.5->mcp-neo4j-cypher) (6.0.3)
# Requirement already satisfied: pathable<0.5.0,>=0.4.1 in c:\users\hahtsham\work\agent\lib\site-packages (from jsonschema-path>=0.3.4->fastmcp>=2.10.5->mcp-neo4j-cypher) (0.4.4)
# Requirement already satisfied: referencing<0.37.0 in c:\users\hahtsham\work\agent\lib\site-packages (from jsonschema-path>=0.3.4->fastmcp>=2.10.5->mcp-neo4j-cypher) (0.36.2)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in c:\users\hahtsham\work\agent\lib\site-packages (from jsonschema-path>=0.3.4->fastmcp>=2.10.5->mcp-neo4j-cypher) (2.32.5)
# Requirement already satisfied: rpds-py>=0.7.0 in c:\users\hahtsham\work\agent\lib\site-packages (from referencing<0.37.0->jsonschema-path>=0.3.4->fastmcp>=2.10.5->mcp-neo4j-cypher) (0.27.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\hahtsham\work\agent\lib\site-packages (from requests<3.0.0,>=2.31.0->jsonschema-path>=0.3.4->fastmcp>=2.10.5->mcp-neo4j-cypher) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hahtsham\work\agent\lib\site-packages (from requests<3.0.0,>=2.31.0->jsonschema-path>=0.3.4->fastmcp>=2.10.5->mcp-neo4j-cypher) (2.5.0)
# Requirement already satisfied: pywin32-ctypes>=0.2.0 in c:\users\hahtsham\work\agent\lib\site-packages (from keyring>=25.6.0->py-key-value-aio[disk,keyring,memory]<0.4.0,>=0.3.0->fastmcp>=2.10.5->mcp-neo4j-cypher) (0.2.3)
# Requirement already satisfied: jaraco.classes in c:\users\hahtsham\work\agent\lib\site-packages (from keyring>=25.6.0->py-key-value-aio[disk,keyring,memory]<0.4.0,>=0.3.0->fastmcp>=2.10.5->mcp-neo4j-cypher) (3.4.0)
# Requirement already satisfied: jaraco.functools in c:\users\hahtsham\work\agent\lib\site-packages (from keyring>=25.6.0->py-key-value-aio[disk,keyring,memory]<0.4.0,>=0.3.0->fastmcp>=2.10.5->mcp-neo4j-cypher) (4.3.0)
# Requirement already satisfied: jaraco.context in c:\users\hahtsham\work\agent\lib\site-packages (from keyring>=25.6.0->py-key-value-aio[disk,keyring,memory]<0.4.0,>=0.3.0->fastmcp>=2.10.5->mcp-neo4j-cypher) (6.0.1)
# Requirement already satisfied: httpx-sse>=0.4 in c:\users\hahtsham\work\agent\lib\site-packages (from mcp>=1.24.0->fastmcp>=2.10.5->mcp-neo4j-cypher) (0.4.3)
# Requirement already satisfied: jsonschema>=4.20.0 in c:\users\hahtsham\work\agent\lib\site-packages (from mcp>=1.24.0->fastmcp>=2.10.5->mcp-neo4j-cypher) (4.25.1)
# Requirement already satisfied: pydantic-settings>=2.5.2 in c:\users\hahtsham\work\agent\lib\site-packages (from mcp>=1.24.0->fastmcp>=2.10.5->mcp-neo4j-cypher) (2.11.0)
# Requirement already satisfied: pyjwt>=2.10.1 in c:\users\hahtsham\work\agent\lib\site-packages (from pyjwt[crypto]>=2.10.1->mcp>=1.24.0->fastmcp>=2.10.5->mcp-neo4j-cypher) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\users\hahtsham\work\agent\lib\site-packages (from mcp>=1.24.0->fastmcp>=2.10.5->mcp-neo4j-cypher) (0.0.20)
# Requirement already satisfied: pywin32>=310 in c:\users\hahtsham\work\agent\lib\site-packages (from mcp>=1.24.0->fastmcp>=2.10.5->mcp-neo4j-cypher) (311)
# Requirement already satisfied: sse-starlette>=1.6.1 in c:\users\hahtsham\work\agent\lib\site-packages (from mcp>=1.24.0->fastmcp>=2.10.5->mcp-neo4j-cypher) (3.0.3)
# Requirement already satisfied: starlette>=0.27 in c:\users\hahtsham\work\agent\lib\site-packages (from mcp>=1.24.0->fastmcp>=2.10.5->mcp-neo4j-cypher) (0.48.0)
# Requirement already satisfied: typing-inspection>=0.4.1 in c:\users\hahtsham\work\agent\lib\site-packages (from mcp>=1.24.0->fastmcp>=2.10.5->mcp-neo4j-cypher) (0.4.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\hahtsham\work\agent\lib\site-packages (from pydantic>=2.10.1->mcp-neo4j-cypher) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\hahtsham\work\agent\lib\site-packages (from pydantic>=2.10.1->mcp-neo4j-cypher) (2.33.2)
# Requirement already satisfied: sniffio>=1.1 in c:\users\hahtsham\work\agent\lib\site-packages (from anyio->httpx>=0.28.1->fastmcp>=2.10.5->mcp-neo4j-cypher) (1.3.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\hahtsham\work\agent\lib\site-packages (from jsonschema>=4.20.0->mcp>=1.24.0->fastmcp>=2.10.5->mcp-neo4j-cypher) (2025.9.1)
# Requirement already satisfied: pytz in c:\users\hahtsham\work\agent\lib\site-packages (from neo4j>=5.26.0->mcp-neo4j-cypher) (2025.2)
# Requirement already satisfied: email-validator>=2.0.0 in c:\users\hahtsham\work\agent\lib\site-packages (from pydantic[email]>=2.11.7->fastmcp>=2.10.5->mcp-neo4j-cypher) (2.3.0)
# Requirement already satisfied: dnspython>=2.0.0 in c:\users\hahtsham\work\agent\lib\site-packages (from email-validator>=2.0.0->pydantic[email]>=2.11.7->fastmcp>=2.10.5->mcp-neo4j-cypher) (2.8.0)
# Requirement already satisfied: cloudpickle>=3.1.1 in c:\users\hahtsham\work\agent\lib\site-packages (from pydocket>=0.15.5->fastmcp>=2.10.5->mcp-neo4j-cypher) (3.1.2)
# Requirement already satisfied: fakeredis>=2.32.1 in c:\users\hahtsham\work\agent\lib\site-packages (from fakeredis[lua]>=2.32.1->pydocket>=0.15.5->fastmcp>=2.10.5->mcp-neo4j-cypher) (2.32.1)
# Requirement already satisfied: opentelemetry-api>=1.33.0 in c:\users\hahtsham\work\agent\lib\site-packages (from pydocket>=0.15.5->fastmcp>=2.10.5->mcp-neo4j-cypher) (1.39.1)
# Requirement already satisfied: opentelemetry-exporter-prometheus>=0.60b0 in c:\users\hahtsham\work\agent\lib\site-packages (from pydocket>=0.15.5->fastmcp>=2.10.5->mcp-neo4j-cypher) (0.60b1)
# Requirement already satisfied: opentelemetry-instrumentation>=0.60b0 in c:\users\hahtsham\work\agent\lib\site-packages (from pydocket>=0.15.5->fastmcp>=2.10.5->mcp-neo4j-cypher) (0.60b1)
# Requirement already satisfied: prometheus-client>=0.21.1 in c:\users\hahtsham\work\agent\lib\site-packages (from pydocket>=0.15.5->fastmcp>=2.10.5->mcp-neo4j-cypher) (0.23.1)
# Requirement already satisfied: python-json-logger>=2.0.7 in c:\users\hahtsham\work\agent\lib\site-packages (from pydocket>=0.15.5->fastmcp>=2.10.5->mcp-neo4j-cypher) (4.0.0)
# Requirement already satisfied: redis>=5 in c:\users\hahtsham\work\agent\lib\site-packages (from pydocket>=0.15.5->fastmcp>=2.10.5->mcp-neo4j-cypher) (6.4.0)
# Requirement already satisfied: typer>=0.15.1 in c:\users\hahtsham\work\agent\lib\site-packages (from pydocket>=0.15.5->fastmcp>=2.10.5->mcp-neo4j-cypher) (0.16.1)
# Requirement already satisfied: sortedcontainers>=2 in c:\users\hahtsham\work\agent\lib\site-packages (from fakeredis>=2.32.1->fakeredis[lua]>=2.32.1->pydocket>=0.15.5->fastmcp>=2.10.5->mcp-neo4j-cypher) (2.4.0)
# Requirement already satisfied: lupa>=2.1 in c:\users\hahtsham\work\agent\lib\site-packages (from fakeredis[lua]>=2.32.1->pydocket>=0.15.5->fastmcp>=2.10.5->mcp-neo4j-cypher) (2.6)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\hahtsham\work\agent\lib\site-packages (from opentelemetry-api>=1.33.0->pydocket>=0.15.5->fastmcp>=2.10.5->mcp-neo4j-cypher) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\hahtsham\work\agent\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.33.0->pydocket>=0.15.5->fastmcp>=2.10.5->mcp-neo4j-cypher) (3.23.0)
# Requirement already satisfied: opentelemetry-sdk~=1.39.1 in c:\users\hahtsham\work\agent\lib\site-packages (from opentelemetry-exporter-prometheus>=0.60b0->pydocket>=0.15.5->fastmcp>=2.10.5->mcp-neo4j-cypher) (1.39.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in c:\users\hahtsham\work\agent\lib\site-packages (from opentelemetry-sdk~=1.39.1->opentelemetry-exporter-prometheus>=0.60b0->pydocket>=0.15.5->fastmcp>=2.10.5->mcp-neo4j-cypher) (0.60b1)
# Requirement already satisfied: packaging>=18.0 in c:\users\hahtsham\work\agent\lib\site-packages (from opentelemetry-instrumentation>=0.60b0->pydocket>=0.15.5->fastmcp>=2.10.5->mcp-neo4j-cypher) (25.0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\hahtsham\work\agent\lib\site-packages (from opentelemetry-instrumentation>=0.60b0->pydocket>=0.15.5->fastmcp>=2.10.5->mcp-neo4j-cypher) (1.17.3)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\hahtsham\work\agent\lib\site-packages (from cryptography->authlib>=1.6.5->fastmcp>=2.10.5->mcp-neo4j-cypher) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\hahtsham\work\agent\lib\site-packages (from cffi>=2.0.0->cryptography->authlib>=1.6.5->fastmcp>=2.10.5->mcp-neo4j-cypher) (2.23)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\hahtsham\work\agent\lib\site-packages (from rich>=13.9.4->fastmcp>=2.10.5->mcp-neo4j-cypher) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\hahtsham\work\agent\lib\site-packages (from rich>=13.9.4->fastmcp>=2.10.5->mcp-neo4j-cypher) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\hahtsham\work\agent\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->fastmcp>=2.10.5->mcp-neo4j-cypher) (0.1.2)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\hahtsham\work\agent\lib\site-packages (from tiktoken>=0.11.0->mcp-neo4j-cypher) (2025.9.18)
# Requirement already satisfied: click>=8.0.0 in c:\users\hahtsham\work\agent\lib\site-packages (from typer>=0.15.1->pydocket>=0.15.5->fastmcp>=2.10.5->mcp-neo4j-cypher) (8.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\hahtsham\work\agent\lib\site-packages (from typer>=0.15.1->pydocket>=0.15.5->fastmcp>=2.10.5->mcp-neo4j-cypher) (1.5.4)
# Requirement already satisfied: colorama in c:\users\hahtsham\work\agent\lib\site-packages (from click>=8.0.0->typer>=0.15.1->pydocket>=0.15.5->fastmcp>=2.10.5->mcp-neo4j-cypher) (0.4.6)
# Requirement already satisfied: more-itertools in c:\users\hahtsham\work\agent\lib\site-packages (from jaraco.classes->keyring>=25.6.0->py-key-value-aio[disk,keyring,memory]<0.4.0,>=0.3.0->fastmcp>=2.10.5->mcp-neo4j-cypher) (10.8.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
def find_movie_recommendations(
    movie_title: str, min_user_rating: float = 4.0, limit: int = 10
) -> list[dict[str, Any]]:
        """
        Search the database movie recommendations based on movie title and rating criteria.
        """

        query = """
    MATCH (target:Movie)
    WHERE target.title = $movieTitle
    MATCH (target)<-[r1:RATED]-(u:User)
    WHERE r1.rating >= $minRating
    MATCH (u)-[r2:RATED]->(similar:Movie)
    WHERE similar <> target 
    AND r2.rating >= $minRating 
    AND similar.imdbRating IS NOT NULL
    WITH similar, count(*) as supporters, avg(r2.rating) as avgRating
    WHERE supporters >= 10
    RETURN similar.title, similar.year, similar.imdbRating, 
        supporters as people_who_loved_both, 
        round(avgRating, 2) as avg_rating_by_target_lovers
    ORDER BY supporters DESC, avgRating DESC
    LIMIT $limit
        """

        driver = GraphDatabase.driver(
            os.getenv("NEO4J_URI"),
            auth=(os.getenv("NEO4J_USERNAME"), os.getenv("NEO4J_PASSWORD")),
        )

        results = driver.execute_query(
            query,
            parameters_={"movieTitle": movie_title, "minRating": min_user_rating, "limit": limit},
            database_=os.getenv("NEO4J_DATABASE"),
            routing_=RoutingControl.READ,
            result_transformer_=lambda r: r.data(),
        )
        return results
    
class FindMovieRecommendationsInput(BaseModel):
    movie_title: str = Field(
        ...,
        description="The title of the movie to find recommendations for. If beginning with 'The', then will follow format of 'Title, The'.",
    )
    min_user_rating: float = Field(
        default=4.0,
        description="The minimum rating of the movie to find recommendations for. ",
        ge=0.5,
        le=5.0,
    )
    limit: int = Field(
        default=10,
        description="The maximum number of recommendations to return. ",
        ge=1,
    )


find_movie_recommendations_tool = StructuredTool.from_function(
    func=find_movie_recommendations,  #           -> The function that the tool calls when executed
    # name=...,                                   -> this is populated by the function name
    # description=...,                            -> this is populated by the function docstring
    args_schema=FindMovieRecommendationsInput,  # -> The input schema for the tool
    return_direct=False,  #                       -> Whether to return the raw result to the user
    # coroutine=...,                              -> An async version of the function
)


CONFIG = {"configurable": {"thread_id": "1"}}






SYSTEM_PROMPT = """You are a Neo4j expert that knows how to write Cypher queries to address movie questions.
As a Cypher expert, when writing queries:
* You must always ensure you have the data model schema to inform your queries
* If an error is returned from the database, you may refactor your query or ask the user to provide additional information
* If an empty result is returned, use your best judgement to determine if the query is correct.

If using a tool that does NOT require writing a Cypher query, you do not need the database schema.

As a well respected movie expert:
* Ensure that you provide detailed responses with citations to the underlying data"""



def pre_model_hook(state: AgentState) -> dict[str, list[AnyMessage]]:
    """
    This function will be called every time before the node that calls LLM.

    Documentation:
    https://langchain-ai.github.io/langgraph/how-tos/create-react-agent-manage-message-history/?h=create_react_agent

    Parameters
    ----------
    state : AgentState
        The state of the agent.

    Returns
    -------
    dict[str, list[AnyMessage]]
        The updated messages to pass to the LLM as context.
    """

    trimmed_messages = trim_messages(
        state["messages"],
        strategy="last",
        token_counter=count_tokens_approximately,
        max_tokens=30_000,
        start_on="human",
        end_on=("human", "tool"),
        include_system=True,  # -> We always want to include the system prompt in the context
    )
    # You can return updated messages either under:
    # `llm_input_messages` -> To keep the original message history unmodified in the graph state and pass the updated history only as the input to the LLM
    # `messages`           -> To overwrite the original message history in the graph state with the updated history
    return {"llm_input_messages": trimmed_messages}



neo4j_cypher_mcp = StdioServerParameters(
    command="uvx",
    args=["mcp-neo4j-cypher", "--transport", "stdio"],
    env={
        "NEO4J_URI": os.getenv("NEO4J_URI"),
        "NEO4J_USERNAME": os.getenv("NEO4J_USERNAME"),
        "NEO4J_PASSWORD": os.getenv("NEO4J_PASSWORD"),
        "NEO4J_DATABASE": os.getenv("NEO4J_DATABASE"),
    },
)

async def print_astream(async_stream, output_messages_key: str = "llm_input_messages") -> None:
    """
    Print the stream of messages from the agent.

    Based on the documentation:
    https://langchain-ai.github.io/langgraph/how-tos/create-react-agent-manage-message-history/?h=create_react_agent#keep-the-original-message-history-unmodified

    Parameters
    ----------
    async_stream : AsyncGenerator[dict[str, dict[str, list[AnyMessage]]], None]
        The stream of messages from the agent.
    output_messages_key : str, optional
        The key to use for the output messages, by default "llm_input_messages".
    """

    async for chunk in async_stream:
        for node, update in chunk.items():
            print(f"Update from node: {node}")
            messages_key = output_messages_key if node == "pre_model_hook" else "messages"
            for message in update[messages_key]:
                if isinstance(message, tuple):
                    print(message)
                else:
                    message.pretty_print()

        print("\n\n")


async def main():
    """
    Main function to run the agent.

    Based on the documentation:
    https://github.com/langchain-ai/langchain-mcp-adapters?tab=readme-ov-file#client
    """

    # start up the MCP server locally and run our agent
    async with stdio_client(neo4j_cypher_mcp) as (read, write):
        async with ClientSession(read, write) as session:
            # Initialize the connection
            await session.initialize()

            # Get tools
            mcp_tools = await load_mcp_tools(session)

            # We only need to get schema and execute read queries from the Cypher MCP server
            allowed_tools = [
                tool for tool in mcp_tools if tool.name in {"get_neo4j_schema", "read_neo4j_cypher"}
            ]

            # We can also add non-mcp tools for our agent to use
            allowed_tools.append(find_movie_recommendations_tool)

            # Create and run the agent
            agent = create_react_agent(
                "openai:gpt-4.1",  #              -> The model to use
                allowed_tools,  #                 -> The tools to use
                pre_model_hook=pre_model_hook,  # -> The function to call before the model is called
                checkpointer=InMemorySaver(),  #  -> The checkpoint to use
                prompt=SYSTEM_PROMPT,  #          -> The system prompt to use
            )

            # conversation loop
            print(
                "\n===================================== Chat =====================================\n"
            )

            while True:
                user_input = input("> ")
                if user_input.lower() in {"exit", "quit", "q"}:
                    break

                await print_astream(
                    agent.astream({"messages": user_input}, config=CONFIG, stream_mode="updates")
                )


# if __name__ == "__main__":
#     asyncio.run(main())
await main()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File c:\Users\hahtsham\work\agent\Lib\site-packages\mcp\os\win32\utilities.py:169, in create_windows_process(command, args, env, errlog, cwd)
#     167 try:
#     168     # First try using anyio with Windows-specific flags to hide console window
# --> 169     process = await anyio.open_process(
#     170         [command, *args],
#     171         env=env,
#     172         # Ensure we don't create console windows for each process
#     173         creationflags=subprocess.CREATE_NO_WINDOW  # type: ignore
#     174         if hasattr(subprocess, "CREATE_NO_WINDOW")
#     175         else 0,
#     176         stderr=errlog,
#     177         cwd=cwd,
#     178     )
#     179 except NotImplementedError:
#     180     # If Windows doesn't support async subprocess creation, use fallback
#
# File c:\Users\hahtsham\work\agent\Lib\site-packages\anyio\_core\_subprocesses.py:190, in open_process(command, stdin, stdout, stderr, cwd, env, startupinfo, creationflags, start_new_session, pass_fds, user, group, extra_groups, umask)
#     188     kwargs["umask"] = umask
# --> 190 return await get_async_backend().open_process(
#     191     command,
#     192     stdin=stdin,
#     193     stdout=stdout,
#     194     stderr=stderr,
#     195     cwd=cwd,
#     196     env=env,
#     197     startupinfo=startupinfo,
#     198     creationflags=creationflags,
#     199     start_new_session=start_new_session,
#     200     pass_fds=pass_fds,
#     201     **kwargs,
#     202 )
#
# File c:\Users\hahtsham\work\agent\Lib\site-packages\anyio\_backends\_asyncio.py:2588, in AsyncIOBackend.open_process(cls, command, stdin, stdout, stderr, **kwargs)
#    2587 else:
# -> 2588     process = await asyncio.create_subprocess_exec(
#    2589         *command,
#    2590         stdin=stdin,
#    2591         stdout=stdout,
#    2592         stderr=stderr,
#    2593         **kwargs,
#    2594     )
#    2596 stdin_stream = StreamWriterWrapper(process.stdin) if process.stdin else None
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\asyncio\subprocess.py:224, in create_subprocess_exec(program, stdin, stdout, stderr, limit, *args, **kwds)
#     222 protocol_factory = lambda: SubprocessStreamProtocol(limit=limit,
#     223                                                     loop=loop)
# --> 224 transport, protocol = await loop.subprocess_exec(
#     225     protocol_factory,
#     226     program, *args,
#     227     stdin=stdin, stdout=stdout,
#     228     stderr=stderr, **kwds)
#     229 return Process(transport, protocol, loop)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\asyncio\base_events.py:1802, in BaseEventLoop.subprocess_exec(self, protocol_factory, program, stdin, stdout, stderr, universal_newlines, shell, bufsize, encoding, errors, text, *args, **kwargs)
#    1801     self._log_subprocess(debug_log, stdin, stdout, stderr)
# -> 1802 transport = await self._make_subprocess_transport(
#    1803     protocol, popen_args, False, stdin, stdout, stderr,
#    1804     bufsize, **kwargs)
#    1805 if self._debug and debug_log is not None:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\asyncio\base_events.py:539, in BaseEventLoop._make_subprocess_transport(self, protocol, args, shell, stdin, stdout, stderr, bufsize, extra, **kwargs)
#     538 """Create subprocess transport."""
# --> 539 raise NotImplementedError
#
# NotImplementedError:
#
# During handling of the above exception, another exception occurred:
#
# UnsupportedOperation                      Traceback (most recent call last)
# File c:\Users\hahtsham\work\agent\Lib\site-packages\mcp\os\win32\utilities.py:209, in _create_windows_fallback_process(command, args, env, errlog, cwd)
#     207 try:
#     208     # Try launching with creationflags to avoid opening a new console window
# --> 209     popen_obj = subprocess.Popen(
#     210         [command, *args],
#     211         stdin=subprocess.PIPE,
#     212         stdout=subprocess.PIPE,
#     213         stderr=errlog,
#     214         env=env,
#     215         cwd=cwd,
#     216         bufsize=0,  # Unbuffered output
#     217         creationflags=getattr(subprocess, "CREATE_NO_WINDOW", 0),
#     218     )
#     219 except Exception:
#     220     # If creationflags failed, fallback without them
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\subprocess.py:1005, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#     988 # Input and output objects. The general principle is like
#     989 # this:
#     990 #
#    (...)   1000 # are -1 when not using PIPEs. The child objects are -1
#    1001 # when not redirecting.
#    1003 (p2cread, p2cwrite,
#    1004  c2pread, c2pwrite,
# -> 1005  errread, errwrite) = self._get_handles(stdin, stdout, stderr)
#    1007 # From here on, raising exceptions may cause file descriptor leakage
#    1008
#    1009 # We wrap OS handles *before* launching the child, otherwise a
#    1010 # quickly terminating child could make our fds unwrappable
#    1011 # (see #8458).
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\subprocess.py:1422, in Popen._get_handles(self, stdin, stdout, stderr)
#    1420 else:
#    1421     # Assuming file-like object
# -> 1422     errwrite = msvcrt.get_osfhandle(stderr.fileno())
#    1423 errwrite = self._make_inheritable(errwrite)
#
# File c:\Users\hahtsham\work\agent\Lib\site-packages\ipykernel\iostream.py:372, in OutStream.fileno(self)
#     371 msg = "fileno"
# --> 372 raise io.UnsupportedOperation(msg)
#
# UnsupportedOperation: fileno
#
# During handling of the above exception, another exception occurred:
#
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[20], line 212
#     205                 await print_astream(
#     206                     agent.astream({"messages": user_input}, config=CONFIG, stream_mode="updates")
#     207                 )
#     210 # if __name__ == "__main__":
#     211 #     asyncio.run(main())
# --> 212 await main()
#
# Cell In[20], line 170, in main()
#     162 """
#     163 Main function to run the agent.
#     164
#     165 Based on the documentation:
#     166 https://github.com/langchain-ai/langchain-mcp-adapters?tab=readme-ov-file#client
#     167 """
#     169 # start up the MCP server locally and run our agent
# --> 170 async with stdio_client(neo4j_cypher_mcp) as (read, write):
#     171     async with ClientSession(read, write) as session:
#     172         # Initialize the connection
#     173         await session.initialize()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\contextlib.py:214, in _AsyncGeneratorContextManager.__aenter__(self)
#     212 del self.args, self.kwds, self.func
#     213 try:
# --> 214     return await anext(self.gen)
#     215 except StopAsyncIteration:
#     216     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\hahtsham\work\agent\Lib\site-packages\mcp\client\stdio\__init__.py:124, in stdio_client(server, errlog)
#     121     command = _get_executable_command(server.command)
#     123     # Open process with stderr piped for capture
# --> 124     process = await _create_platform_compatible_process(
#     125         command=command,
#     126         args=server.args,
#     127         env=({**get_default_environment(), **server.env} if server.env is not None else get_default_environment()),
#     128         errlog=errlog,
#     129         cwd=server.cwd,
#     130     )
#     131 except OSError:
#     132     # Clean up streams if process creation fails
#     133     await read_stream.aclose()
#
# File c:\Users\hahtsham\work\agent\Lib\site-packages\mcp\client\stdio\__init__.py:249, in _create_platform_compatible_process(command, args, env, errlog, cwd)
#     242 """
#     243 Creates a subprocess in a platform-compatible way.
#     244
#     245 Unix: Creates process in a new session/process group for killpg support
#     246 Windows: Creates process in a Job Object for reliable child termination
#     247 """
#     248 if sys.platform == "win32":  # pragma: no cover
# --> 249     process = await create_windows_process(command, args, env, errlog, cwd)
#     250 else:
#     251     process = await anyio.open_process(
#     252         [command, *args],
#     253         env=env,
#    (...)    256         start_new_session=True,
#     257     )  # pragma: no cover
#
# File c:\Users\hahtsham\work\agent\Lib\site-packages\mcp\os\win32\utilities.py:181, in create_windows_process(command, args, env, errlog, cwd)
#     169     process = await anyio.open_process(
#     170         [command, *args],
#     171         env=env,
#    (...)    177         cwd=cwd,
#     178     )
#     179 except NotImplementedError:
#     180     # If Windows doesn't support async subprocess creation, use fallback
# --> 181     process = await _create_windows_fallback_process(command, args, env, errlog, cwd)
#     182 except Exception:
#     183     # Try again without creation flags
#     184     process = await anyio.open_process(
#     185         [command, *args],
#     186         env=env,
#     187         stderr=errlog,
#     188         cwd=cwd,
#     189     )
#
# File c:\Users\hahtsham\work\agent\Lib\site-packages\mcp\os\win32\utilities.py:221, in _create_windows_fallback_process(command, args, env, errlog, cwd)
#     209     popen_obj = subprocess.Popen(
#     210         [command, *args],
#     211         stdin=subprocess.PIPE,
#    (...)    217         creationflags=getattr(subprocess, "CREATE_NO_WINDOW", 0),
#     218     )
#     219 except Exception:
#     220     # If creationflags failed, fallback without them
# --> 221     popen_obj = subprocess.Popen(
#     222         [command, *args],
#     223         stdin=subprocess.PIPE,
#     224         stdout=subprocess.PIPE,
#     225         stderr=errlog,
#     226         env=env,
#     227         cwd=cwd,
#     228         bufsize=0,
#     229     )
#     230 return FallbackProcess(popen_obj)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\subprocess.py:1005, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#     986         raise ValueError(f"User ID cannot be negative, got {uid}")
#     988 # Input and output objects. The general principle is like
#     989 # this:
#     990 #
#    (...)   1000 # are -1 when not using PIPEs. The child objects are -1
#    1001 # when not redirecting.
#    1003 (p2cread, p2cwrite,
#    1004  c2pread, c2pwrite,
# -> 1005  errread, errwrite) = self._get_handles(stdin, stdout, stderr)
#    1007 # From here on, raising exceptions may cause file descriptor leakage
#    1008
#    1009 # We wrap OS handles *before* launching the child, otherwise a
#    1010 # quickly terminating child could make our fds unwrappable
#    1011 # (see #8458).
#    1013 if _mswindows:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\subprocess.py:1422, in Popen._get_handles(self, stdin, stdout, stderr)
#    1419         errwrite = msvcrt.get_osfhandle(stderr)
#    1420     else:
#    1421         # Assuming file-like object
# -> 1422         errwrite = msvcrt.get_osfhandle(stderr.fileno())
#    1423     errwrite = self._make_inheritable(errwrite)
#    1425 return (p2cread, p2cwrite,
#    1426         c2pread, c2pwrite,
#    1427         errread, errwrite)
#
# File c:\Users\hahtsham\work\agent\Lib\site-packages\ipykernel\iostream.py:372, in OutStream.fileno(self)
#     370     return self._original_stdstream_copy
#     371 msg = "fileno"
# --> 372 raise io.UnsupportedOperation(msg)
#
# UnsupportedOperation: fileno

# %%
from dotenv import load_dotenv
load_dotenv()
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
allowed_tools = []
allowed_tools.append(find_movie_recommendations_tool)
agent = create_react_agent(
                "openai:gpt-4.1",  #              -> The model to use
                allowed_tools,  #                 -> The tools to use
                pre_model_hook=pre_model_hook,  # -> The function to call before the model is called
                checkpointer=InMemorySaver(),  #  -> The checkpoint to use
                prompt=SYSTEM_PROMPT,  #          -> The system prompt to use
            )
# Out:
# C:\Users\hahtsham\AppData\Local\Temp\ipykernel_28272\4228065506.py:6: LangGraphDeprecatedSinceV10: create_react_agent has been moved to `langchain.agents`. Please update your import to `from langchain.agents import create_agent`. Deprecated in LangGraph V1.0 to be removed in V2.0.
#   agent = create_react_agent(
